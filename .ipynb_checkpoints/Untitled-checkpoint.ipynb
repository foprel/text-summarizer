# %%
from app import Smmry
import io

text = io.open('article_1.txt', 'r', encoding='utf-8').read()
smmry = Smmry(text, lang="english")
smmry.summarize(length=2)
# Out:
# Stimulating innovation As innovation comes at a cost, the government realizes that it needs more ‘carrots’ to stimulate innovation rather than use sticks to punish undesired behavior.
#
# Funding innovation Stimulating innovation is not only done through tax credits or cash grants.
# Time elapsed: 0.886549711227417
# Reduced by: 97%

# %%
smmry.tokenize()

# %%
smmry.preprocess()
# Out:
# [['article',
#   'innovation',
#   'required',
#   'counter',
#   'climate',
#   'change',
#   'climate',
#   'accord',
#   'blog',
#   'series',
#   'order',
#   'counter',
#   'climate',
#   'change',
#   'innovation',
#   'key'],
#  ['however', 'innovation', 'time consuming', 'expensive'],
#  ['government', 'realizes', 'importantly', 'realizes', 'time', 'change'],
#  ['reach',
#   'climate',
#   'accord',
#   'goals',
#   'dutch',
#   'government',
#   'implemented',
#   'set',
#   'measures',
#   'consist',
#   'so called',
#   'carrots',
#   'sticks'],
#  ['read',
#   'article',
#   'find',
#   'measures',
#   'look',
#   'securing',
#   'funding',
#   'innovation',
#   'projects'],
#  ['add',
#   'bookmarks',
#   'reason',
#   'innovation',
#   'dutch',
#   'government',
#   'big',
#   'challenge',
#   'meet',
#   'various',
#   'climate',
#   'goals',
#   'short',
#   'long',
#   'term'],
#  ['lawsuit',
#   'forces',
#   'government',
#   'speed',
#   'actions',
#   'reduce',
#   'greenhouse',
#   'gas',
#   'emissions',
#   'end',
#   'compared',
#   'emissions'],
#  ['also',
#   'light',
#   'paris',
#   'agreement',
#   'emission',
#   'greenhouse',
#   'gasses',
#   'reduced',
#   'compared'],
#  ['reach',
#   'goals',
#   'dutch',
#   'government',
#   'implemented',
#   'set',
#   'measures',
#   'consist',
#   'so called',
#   'carrots',
#   'sticks'],
#  ['sticks',
#   'measures',
#   'implemented',
#   'punish',
#   'undesired',
#   'behavior',
#   'case',
#   'emission',
#   'greenhouse',
#   'gasses'],
#  ['examples', 'measures', 'taxes', 'fines', 'prohibitions'],
#  ['carrots',
#   'hand',
#   'implemented',
#   'stimulate',
#   'reward',
#   'behavior',
#   'contributes',
#   'meeting',
#   'climate',
#   'goals'],
#  ['think', 'tax', 'benefits', 'cheap', 'funding', 'even', 'cash', 'grants'],
#  ['comes',
#   'incentives',
#   'stimulating',
#   'known',
#   'technologies',
#   'benefit',
#   'reduction',
#   'greenhouse',
#   'gas',
#   'emissions',
#   'remain',
#   'focal',
#   'point'],
#  ['however',
#   'disruptive',
#   'technologies',
#   'meeting',
#   'high',
#   'level',
#   'innovation',
#   'required',
#   'able',
#   'meet',
#   'climate',
#   'goals'],
#  ['stimulating',
#   'already',
#   'know',
#   'great',
#   'enhancing',
#   'opportunity',
#   'groundbreaking',
#   'innovations',
#   'would',
#   'even',
#   'better'],
#  ['innovation',
#   'stimulation',
#   'grants',
#   'incentives',
#   'government',
#   'spend',
#   'approximately',
#   'million',
#   'eur',
#   'per',
#   'year',
#   'reduce',
#   'greenhouse',
#   'gas',
#   'emissions'],
#  ['total',
#   'million',
#   'eur',
#   'reserved',
#   'innovation',
#   'pilots',
#   'greenhouse',
#   'gas',
#   'emissions',
#   'reducing',
#   'technology',
#   'million',
#   'eur',
#   'hydrogen',
#   'projects',
#   'million',
#   'eur',
#   'carbon',
#   'capture',
#   'utilization',
#   'storage',
#   'million',
#   'eur',
#   'rapid',
#   'execution',
#   'greenhouse',
#   'gas',
#   'emissions',
#   'reductions',
#   'million',
#   'eur',
#   'circular',
#   'economy',
#   'also',
#   'government',
#   'investing',
#   'million',
#   'eur',
#   'innovation',
#   'electricity',
#   'companies',
#   'large',
#   'contributors',
#   'reducing',
#   'co',
#   'emissions'],
#  ['furthermore',
#   'government',
#   'wants',
#   'change',
#   'energy',
#   'regulations',
#   'make',
#   'easier',
#   'generate',
#   'store',
#   'energy'],
#  ['stimulating',
#   'innovation',
#   'innovation',
#   'comes',
#   'cost',
#   'government',
#   'realizes',
#   'needs',
#   'carrots',
#   'stimulate',
#   'innovation',
#   'rather',
#   'use',
#   'sticks',
#   'punish',
#   'undesired',
#   'behavior'],
#  ['stimulation', 'available', 'different', 'sectors', 'different', 'ways'],
#  ['example',
#   'dutch',
#   'wbso',
#   'innovation',
#   'stimulated',
#   'tax',
#   'credit',
#   'dutch',
#   'wage',
#   'taxes',
#   'nice',
#   'example',
#   'carrot',
#   'stimulate',
#   'innovation'],
#  ['way',
#   'companies',
#   'stimulated',
#   'innovate',
#   'new',
#   'products',
#   'production',
#   'processes',
#   'production',
#   'site'],
#  ['however',
#   'stimulate',
#   'innovation',
#   'environmental',
#   'reasons',
#   'significant',
#   'cash',
#   'grants',
#   'available',
#   'stimulate',
#   'new',
#   'expensive',
#   'methods',
#   'generate',
#   'renewable',
#   'energy',
#   'cost',
#   'efficient',
#   'way'],
#  ['able',
#   'demonstrate',
#   'new',
#   'methods',
#   'government',
#   'eager',
#   'stimulate',
#   'projects',
#   'would',
#   'otherwise',
#   'expensive',
#   'innovate',
#   'demonstrate',
#   'industrial',
#   'scale'],
#  ['high',
#   'costs',
#   'raw',
#   'material',
#   'research',
#   'costs',
#   'nice',
#   'see',
#   'funding',
#   'available',
#   'innovation',
#   'stimulated'],
#  ['examples',
#   'many',
#   'available',
#   'subsidy',
#   'renewable',
#   'energy',
#   'sre',
#   'goal',
#   'program',
#   'stimulate',
#   'innovation',
#   'field',
#   'renewable',
#   'energy'],
#  ['example',
#   'efficient',
#   'ways',
#   'produce',
#   'renewable',
#   'energy',
#   'improved',
#   'efficiency',
#   'solar',
#   'panels',
#   'reduction',
#   'maintenance',
#   'cost',
#   'causing',
#   'lower',
#   'costs',
#   'produce',
#   'renewable',
#   'energy'],
#  ['demonstration',
#   'energy innovation',
#   'dei',
#   'focus',
#   'dei',
#   'program',
#   'pilot',
#   'demonstration',
#   'projects',
#   'aiming',
#   'develop',
#   'innovative',
#   'technologies',
#   'accelerating',
#   'co',
#   'emission',
#   'reduction'],
#  ['funding',
#   'innovation',
#   'stimulating',
#   'innovation',
#   'done',
#   'tax',
#   'credits',
#   'cash',
#   'grants'],
#  ['also',
#   'certain',
#   'finance',
#   'products',
#   'available',
#   'profitable',
#   'conditions',
#   'capital',
#   'generated',
#   'finance',
#   'innovation'],
#  ['achieving',
#   'sustainability',
#   'innovation',
#   'involves',
#   'mobilizing',
#   'public',
#   'private',
#   'financing',
#   'sources'],
#  ['currently',
#   'difficult',
#   'projects',
#   'social',
#   'impact',
#   'obtain',
#   'funding',
#   'uncertainty',
#   'risk return',
#   'ratio',
#   'long',
#   'uncertain',
#   'return',
#   'investment'],
#  ['public',
#   'investment',
#   'opposed',
#   'grants',
#   'envisaged',
#   'stimulate',
#   'investment',
#   'innovation',
#   'leveraging',
#   'multiplier',
#   'effect'],
#  ['public',
#   'investment',
#   'turn',
#   'generate',
#   'investment',
#   'worth',
#   'several',
#   'times',
#   'loan',
#   'attracting',
#   'third',
#   'party',
#   'private',
#   'co investment'],
#  ['creates',
#   'opportunity',
#   'innovative',
#   'projects',
#   'close',
#   'financing',
#   'shortfalls',
#   'forming',
#   'consortium',
#   'public',
#   'private',
#   'investors'],
#  ['targeting',
#   'market',
#   'gaps',
#   'around',
#   'sustainability',
#   'encourages',
#   'financers',
#   'unlock',
#   'investment',
#   'currently',
#   'slowed',
#   'hindered',
#   'economic',
#   'uncertainty'],
#  ['public', 'financing', 'sources', 'also', 'available', 'netherlands'],
#  ['financing', 'programs', 'connections', 'european', 'financing', 'programs'],
#  ['examples',
#   'current',
#   'funds',
#   'stimulation',
#   'funds',
#   'available',
#   'european',
#   'fund',
#   'strategic',
#   'investments',
#   'efsi',
#   'key',
#   'investment',
#   'initiative',
#   'european',
#   'investment',
#   'bank',
#   'juncker',
#   'plan',
#   'help',
#   'overcome',
#   'current',
#   'investment',
#   'gap',
#   'eu',
#   'funding',
#   'projects',
#   'higher',
#   'risk',
#   'profile',
#   'usually',
#   'taken',
#   'bank'],
#  ['approximately',
#   'smes',
#   'benefit',
#   'financing',
#   'focusses',
#   'sectors',
#   'key',
#   'importance',
#   'european',
#   'economy',
#   'including',
#   'strategic',
#   'infrastructure',
#   'including',
#   'digital',
#   'transport',
#   'energy'],
#  ['education', 'research', 'development', 'innovation'],
#  ['renewable', 'energy', 'resource', 'efficiency'],
#  ['connecting',
#   'europe',
#   'facility',
#   'cef',
#   'key',
#   'eu',
#   'funding',
#   'instrument',
#   'developed',
#   'specifically',
#   'direct',
#   'investment',
#   'towards',
#   'european',
#   'transport',
#   'energy',
#   'digital',
#   'infrastructure',
#   'address',
#   'identified',
#   'missing',
#   'links',
#   'bottlenecks',
#   'promote',
#   'sustainability'],
#  ['longer',
#   'periods',
#   'time',
#   'multiple',
#   'billions',
#   'euros',
#   'available',
#   'within',
#   'netherlands',
#   'finance',
#   'innovation'],
#  ['obtaining',
#   'funds',
#   'could',
#   'accelerator',
#   'towards',
#   'sustainable',
#   'society',
#   'could',
#   'advantageous',
#   'conditions'],
#  ['looking',
#   'forward',
#   'see',
#   'establishment',
#   'new',
#   'funds',
#   'help',
#   'close',
#   'sustainability',
#   'funding',
#   'gaps',
#   'invest nl',
#   'onwards',
#   'invest nl',
#   'planned',
#   'contribute',
#   'financing',
#   'social',
#   'transition',
#   'challenges',
#   'investments',
#   'areas',
#   'energy',
#   'sustainability',
#   'mobility',
#   'investment',
#   'capital',
#   'billion',
#   'eur'],
#  ['proposed',
#   'national',
#   'financing',
#   'institution',
#   'submit',
#   'projects',
#   'well',
#   'co finance'],
#  ['investeu',
#   'bring',
#   'together',
#   'one',
#   'roof',
#   'efsi',
#   'eu',
#   'financial',
#   'instruments',
#   'currently',
#   'available'],
#  ['triggering',
#   'least',
#   'billion',
#   'eur',
#   'additional',
#   'investment',
#   'programme',
#   'aims',
#   'give',
#   'additional',
#   'boost',
#   'investment',
#   'innovation',
#   'job',
#   'creation',
#   'europe'],
#  ['deloitte',
#   'supported',
#   'several',
#   'entrepreneurs',
#   'obtaining',
#   'available',
#   'tax',
#   'credits',
#   'cash',
#   'grants',
#   'innovation',
#   'projects'],
#  ['also',
#   'advised',
#   'several',
#   'innovators',
#   'securing',
#   'funding',
#   'either',
#   'support',
#   'preparing',
#   'bankable',
#   'business',
#   'case',
#   'finding',
#   'partners',
#   'provide',
#   'necessary',
#   'funding',
#   'innovation',
#   'projects'],
#  ['learnings',
#   'experience',
#   'securing',
#   'funding',
#   'european',
#   'investment',
#   'bank',
#   'european',
#   'investment',
#   'bank',
#   'offer',
#   'attractive',
#   'funding',
#   'innovative',
#   'companies',
#   'beneficial',
#   'terms'],
#  ['although',
#   'funding',
#   'package',
#   'enables',
#   'lot',
#   'companies',
#   'realize',
#   'envisioned',
#   'growth',
#   'process',
#   'time consuming',
#   'might',
#   'seem',
#   'bureaucratic'],
#  ['please',
#   'bear',
#   'mind',
#   'public',
#   'money',
#   'applying',
#   'come',
#   'well prepared',
#   'definitely',
#   'worth'],
#  ['similar', 'e g'],
#  ['applying',
#   'european',
#   'grant',
#   'order',
#   'secure',
#   'funding',
#   'beneficial',
#   'terms',
#   'adequate',
#   'thorough',
#   'preparation',
#   'key'],
#  ['make',
#   'sure',
#   'read',
#   'definitions',
#   'match',
#   'criteria',
#   'funding',
#   'solution',
#   'going',
#   'adequate',
#   'liquidity',
#   'runway',
#   'absorb',
#   'potential',
#   'delays',
#   'process',
#   'things',
#   'take',
#   'time'],
#  ['conclusion', 'order', 'counter', 'climate', 'change', 'innovation', 'key'],
#  ['however', 'innovation', 'time consuming', 'expensive'],
#  ['government', 'realizes', 'importantly', 'realizes', 'time', 'change'],
#  ['accelerate',
#   'change',
#   'funds',
#   'available',
#   'enable',
#   'necessary',
#   'innovation',
#   'make',
#   'change'],
#  ['starting', 'project', 'right', 'type', 'funding', 'key'],
#  ['sure', 'make', 'right', 'assessment', 'starting', 'innovation', 'project'],
#  ['tax',
#   'credits',
#   'cash',
#   'grants',
#   'favorable',
#   'funding',
#   'might',
#   'applicable',
#   'project',
#   'must',
#   'overlooked']]

# %%
smmry.stem()
# Out:
# [['articl',
#   'innov',
#   'requir',
#   'counter',
#   'climat',
#   'chang',
#   'climat',
#   'accord',
#   'blog',
#   'seri',
#   'order',
#   'counter',
#   'climat',
#   'chang',
#   'innov',
#   'key'],
#  ['howev', 'innov', 'time consum', 'expens'],
#  ['govern', 'realiz', 'import', 'realiz', 'time', 'chang'],
#  ['reach',
#   'climat',
#   'accord',
#   'goal',
#   'dutch',
#   'govern',
#   'implement',
#   'set',
#   'measur',
#   'consist',
#   'so cal',
#   'carrot',
#   'stick'],
#  ['read',
#   'articl',
#   'find',
#   'measur',
#   'look',
#   'secur',
#   'fund',
#   'innov',
#   'project'],
#  ['add',
#   'bookmark',
#   'reason',
#   'innov',
#   'dutch',
#   'govern',
#   'big',
#   'challeng',
#   'meet',
#   'various',
#   'climat',
#   'goal',
#   'short',
#   'long',
#   'term'],
#  ['lawsuit',
#   'forc',
#   'govern',
#   'speed',
#   'action',
#   'reduc',
#   'greenhous',
#   'gas',
#   'emiss',
#   'end',
#   'compar',
#   'emiss'],
#  ['also',
#   'light',
#   'pari',
#   'agreement',
#   'emiss',
#   'greenhous',
#   'gass',
#   'reduc',
#   'compar'],
#  ['reach',
#   'goal',
#   'dutch',
#   'govern',
#   'implement',
#   'set',
#   'measur',
#   'consist',
#   'so cal',
#   'carrot',
#   'stick'],
#  ['stick',
#   'measur',
#   'implement',
#   'punish',
#   'undesir',
#   'behavior',
#   'case',
#   'emiss',
#   'greenhous',
#   'gass'],
#  ['exampl', 'measur', 'tax', 'fine', 'prohibit'],
#  ['carrot',
#   'hand',
#   'implement',
#   'stimul',
#   'reward',
#   'behavior',
#   'contribut',
#   'meet',
#   'climat',
#   'goal'],
#  ['think', 'tax', 'benefit', 'cheap', 'fund', 'even', 'cash', 'grant'],
#  ['come',
#   'incent',
#   'stimul',
#   'known',
#   'technolog',
#   'benefit',
#   'reduct',
#   'greenhous',
#   'gas',
#   'emiss',
#   'remain',
#   'focal',
#   'point'],
#  ['howev',
#   'disrupt',
#   'technolog',
#   'meet',
#   'high',
#   'level',
#   'innov',
#   'requir',
#   'abl',
#   'meet',
#   'climat',
#   'goal'],
#  ['stimul',
#   'alreadi',
#   'know',
#   'great',
#   'enhanc',
#   'opportun',
#   'groundbreak',
#   'innov',
#   'would',
#   'even',
#   'better'],
#  ['innov',
#   'stimul',
#   'grant',
#   'incent',
#   'govern',
#   'spend',
#   'approxim',
#   'million',
#   'eur',
#   'per',
#   'year',
#   'reduc',
#   'greenhous',
#   'gas',
#   'emiss'],
#  ['total',
#   'million',
#   'eur',
#   'reserv',
#   'innov',
#   'pilot',
#   'greenhous',
#   'gas',
#   'emiss',
#   'reduc',
#   'technolog',
#   'million',
#   'eur',
#   'hydrogen',
#   'project',
#   'million',
#   'eur',
#   'carbon',
#   'captur',
#   'util',
#   'storag',
#   'million',
#   'eur',
#   'rapid',
#   'execut',
#   'greenhous',
#   'gas',
#   'emiss',
#   'reduct',
#   'million',
#   'eur',
#   'circular',
#   'economi',
#   'also',
#   'govern',
#   'invest',
#   'million',
#   'eur',
#   'innov',
#   'electr',
#   'compani',
#   'larg',
#   'contributor',
#   'reduc',
#   'co',
#   'emiss'],
#  ['furthermor',
#   'govern',
#   'want',
#   'chang',
#   'energi',
#   'regul',
#   'make',
#   'easier',
#   'generat',
#   'store',
#   'energi'],
#  ['stimul',
#   'innov',
#   'innov',
#   'come',
#   'cost',
#   'govern',
#   'realiz',
#   'need',
#   'carrot',
#   'stimul',
#   'innov',
#   'rather',
#   'use',
#   'stick',
#   'punish',
#   'undesir',
#   'behavior'],
#  ['stimul', 'avail', 'differ', 'sector', 'differ', 'way'],
#  ['exampl',
#   'dutch',
#   'wbso',
#   'innov',
#   'stimul',
#   'tax',
#   'credit',
#   'dutch',
#   'wage',
#   'tax',
#   'nice',
#   'exampl',
#   'carrot',
#   'stimul',
#   'innov'],
#  ['way',
#   'compani',
#   'stimul',
#   'innov',
#   'new',
#   'product',
#   'product',
#   'process',
#   'product',
#   'site'],
#  ['howev',
#   'stimul',
#   'innov',
#   'environment',
#   'reason',
#   'signific',
#   'cash',
#   'grant',
#   'avail',
#   'stimul',
#   'new',
#   'expens',
#   'method',
#   'generat',
#   'renew',
#   'energi',
#   'cost',
#   'effici',
#   'way'],
#  ['abl',
#   'demonstr',
#   'new',
#   'method',
#   'govern',
#   'eager',
#   'stimul',
#   'project',
#   'would',
#   'otherwis',
#   'expens',
#   'innov',
#   'demonstr',
#   'industri',
#   'scale'],
#  ['high',
#   'cost',
#   'raw',
#   'materi',
#   'research',
#   'cost',
#   'nice',
#   'see',
#   'fund',
#   'avail',
#   'innov',
#   'stimul'],
#  ['exampl',
#   'mani',
#   'avail',
#   'subsidi',
#   'renew',
#   'energi',
#   'sre',
#   'goal',
#   'program',
#   'stimul',
#   'innov',
#   'field',
#   'renew',
#   'energi'],
#  ['exampl',
#   'effici',
#   'way',
#   'produc',
#   'renew',
#   'energi',
#   'improv',
#   'effici',
#   'solar',
#   'panel',
#   'reduct',
#   'mainten',
#   'cost',
#   'caus',
#   'lower',
#   'cost',
#   'produc',
#   'renew',
#   'energi'],
#  ['demonstr',
#   'energy innov',
#   'dei',
#   'focus',
#   'dei',
#   'program',
#   'pilot',
#   'demonstr',
#   'project',
#   'aim',
#   'develop',
#   'innov',
#   'technolog',
#   'acceler',
#   'co',
#   'emiss',
#   'reduct'],
#  ['fund',
#   'innov',
#   'stimul',
#   'innov',
#   'done',
#   'tax',
#   'credit',
#   'cash',
#   'grant'],
#  ['also',
#   'certain',
#   'financ',
#   'product',
#   'avail',
#   'profit',
#   'condit',
#   'capit',
#   'generat',
#   'financ',
#   'innov'],
#  ['achiev',
#   'sustain',
#   'innov',
#   'involv',
#   'mobil',
#   'public',
#   'privat',
#   'financ',
#   'sourc'],
#  ['current',
#   'difficult',
#   'project',
#   'social',
#   'impact',
#   'obtain',
#   'fund',
#   'uncertainti',
#   'risk return',
#   'ratio',
#   'long',
#   'uncertain',
#   'return',
#   'invest'],
#  ['public',
#   'invest',
#   'oppos',
#   'grant',
#   'envisag',
#   'stimul',
#   'invest',
#   'innov',
#   'leverag',
#   'multipli',
#   'effect'],
#  ['public',
#   'invest',
#   'turn',
#   'generat',
#   'invest',
#   'worth',
#   'sever',
#   'time',
#   'loan',
#   'attract',
#   'third',
#   'parti',
#   'privat',
#   'co invest'],
#  ['creat',
#   'opportun',
#   'innov',
#   'project',
#   'close',
#   'financ',
#   'shortfal',
#   'form',
#   'consortium',
#   'public',
#   'privat',
#   'investor'],
#  ['target',
#   'market',
#   'gap',
#   'around',
#   'sustain',
#   'encourag',
#   'financ',
#   'unlock',
#   'invest',
#   'current',
#   'slow',
#   'hinder',
#   'econom',
#   'uncertainti'],
#  ['public', 'financ', 'sourc', 'also', 'avail', 'netherland'],
#  ['financ', 'program', 'connect', 'european', 'financ', 'program'],
#  ['exampl',
#   'current',
#   'fund',
#   'stimul',
#   'fund',
#   'avail',
#   'european',
#   'fund',
#   'strateg',
#   'invest',
#   'efsi',
#   'key',
#   'invest',
#   'initi',
#   'european',
#   'invest',
#   'bank',
#   'juncker',
#   'plan',
#   'help',
#   'overcom',
#   'current',
#   'invest',
#   'gap',
#   'eu',
#   'fund',
#   'project',
#   'higher',
#   'risk',
#   'profil',
#   'usual',
#   'taken',
#   'bank'],
#  ['approxim',
#   'smes',
#   'benefit',
#   'financ',
#   'focuss',
#   'sector',
#   'key',
#   'import',
#   'european',
#   'economi',
#   'includ',
#   'strateg',
#   'infrastructur',
#   'includ',
#   'digit',
#   'transport',
#   'energi'],
#  ['educ', 'research', 'develop', 'innov'],
#  ['renew', 'energi', 'resourc', 'effici'],
#  ['connect',
#   'europ',
#   'facil',
#   'cef',
#   'key',
#   'eu',
#   'fund',
#   'instrument',
#   'develop',
#   'specif',
#   'direct',
#   'invest',
#   'toward',
#   'european',
#   'transport',
#   'energi',
#   'digit',
#   'infrastructur',
#   'address',
#   'identifi',
#   'miss',
#   'link',
#   'bottleneck',
#   'promot',
#   'sustain'],
#  ['longer',
#   'period',
#   'time',
#   'multipl',
#   'billion',
#   'euro',
#   'avail',
#   'within',
#   'netherland',
#   'financ',
#   'innov'],
#  ['obtain',
#   'fund',
#   'could',
#   'acceler',
#   'toward',
#   'sustain',
#   'societi',
#   'could',
#   'advantag',
#   'condit'],
#  ['look',
#   'forward',
#   'see',
#   'establish',
#   'new',
#   'fund',
#   'help',
#   'close',
#   'sustain',
#   'fund',
#   'gap',
#   'invest nl',
#   'onward',
#   'invest nl',
#   'plan',
#   'contribut',
#   'financ',
#   'social',
#   'transit',
#   'challeng',
#   'invest',
#   'area',
#   'energi',
#   'sustain',
#   'mobil',
#   'invest',
#   'capit',
#   'billion',
#   'eur'],
#  ['propos',
#   'nation',
#   'financ',
#   'institut',
#   'submit',
#   'project',
#   'well',
#   'co fin'],
#  ['investeu',
#   'bring',
#   'togeth',
#   'one',
#   'roof',
#   'efsi',
#   'eu',
#   'financi',
#   'instrument',
#   'current',
#   'avail'],
#  ['trigger',
#   'least',
#   'billion',
#   'eur',
#   'addit',
#   'invest',
#   'programm',
#   'aim',
#   'give',
#   'addit',
#   'boost',
#   'invest',
#   'innov',
#   'job',
#   'creation',
#   'europ'],
#  ['deloitt',
#   'support',
#   'sever',
#   'entrepreneur',
#   'obtain',
#   'avail',
#   'tax',
#   'credit',
#   'cash',
#   'grant',
#   'innov',
#   'project'],
#  ['also',
#   'advis',
#   'sever',
#   'innov',
#   'secur',
#   'fund',
#   'either',
#   'support',
#   'prepar',
#   'bankabl',
#   'busi',
#   'case',
#   'find',
#   'partner',
#   'provid',
#   'necessari',
#   'fund',
#   'innov',
#   'project'],
#  ['learn',
#   'experi',
#   'secur',
#   'fund',
#   'european',
#   'invest',
#   'bank',
#   'european',
#   'invest',
#   'bank',
#   'offer',
#   'attract',
#   'fund',
#   'innov',
#   'compani',
#   'benefici',
#   'term'],
#  ['although',
#   'fund',
#   'packag',
#   'enabl',
#   'lot',
#   'compani',
#   'realiz',
#   'envis',
#   'growth',
#   'process',
#   'time consum',
#   'might',
#   'seem',
#   'bureaucrat'],
#  ['pleas',
#   'bear',
#   'mind',
#   'public',
#   'money',
#   'appli',
#   'come',
#   'well prepar',
#   'definit',
#   'worth'],
#  ['similar', 'e g'],
#  ['appli',
#   'european',
#   'grant',
#   'order',
#   'secur',
#   'fund',
#   'benefici',
#   'term',
#   'adequ',
#   'thorough',
#   'prepar',
#   'key'],
#  ['make',
#   'sure',
#   'read',
#   'definit',
#   'match',
#   'criteria',
#   'fund',
#   'solut',
#   'go',
#   'adequ',
#   'liquid',
#   'runway',
#   'absorb',
#   'potenti',
#   'delay',
#   'process',
#   'thing',
#   'take',
#   'time'],
#  ['conclus', 'order', 'counter', 'climat', 'chang', 'innov', 'key'],
#  ['howev', 'innov', 'time consum', 'expens'],
#  ['govern', 'realiz', 'import', 'realiz', 'time', 'chang'],
#  ['acceler',
#   'chang',
#   'fund',
#   'avail',
#   'enabl',
#   'necessari',
#   'innov',
#   'make',
#   'chang'],
#  ['start', 'project', 'right', 'type', 'fund', 'key'],
#  ['sure', 'make', 'right', 'assess', 'start', 'innov', 'project'],
#  ['tax',
#   'credit',
#   'cash',
#   'grant',
#   'favor',
#   'fund',
#   'might',
#   'applic',
#   'project',
#   'must',
#   'overlook']]

# %%
smmry.build_similarity_matrix()
# Out:
# array([[0.        , 0.03129429, 0.0221284 , ..., 0.01277584, 0.02365626,
#         0.        ],
#        [0.03049954, 0.        , 0.        , ..., 0.        , 0.03049954,
#         0.        ],
#        [0.04403493, 0.        , 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        ...,
#        [0.01832249, 0.        , 0.        , ..., 0.        , 0.10993495,
#         0.05846517],
#        [0.02556751, 0.03382264, 0.        , ..., 0.08284821, 0.        ,
#         0.02039582],
#        [0.        , 0.        , 0.        , ..., 0.05686986, 0.02632563,
#         0.        ]])
